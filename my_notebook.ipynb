# %%
```xml
<!-- filepath: /Users/tt/gitRepos/new-madonna-spa-site/my_notebook.ipynb -->
<VSCode.Cell language="markdown">
# Kalman Filter Notebook
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 1. Section: Import Necessary Libraries
</VSCode.Cell>
<VSCode.Cell language="python">
import numpy as np
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 2. Section: Define System Model
</VSCode.Cell>
<VSCode.Cell language="python">
# State transition matrix (F)
x = np.array([[1]])
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 3. Section: Define Measurement Model
</VSCode.Cell>
<VSCode.Cell language="python">
# Measurement matrix (H)
y = np.array([[1]])
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 4. Section: Initialize Kalman Filter Variables
</VSCode.Cell>
<VSCode.Cell language="python">
x = np.array([[0]])
P = np.array([[1]])
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 5. Section: Kalman Filter Prediction Step
</VSCode.Cell>
<VSCode.Cell language="python">
# Prediction step
x_pred = x
P_pred = P
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 6. Section: Kalman Filter Update Step
</VSCode.Cell>
<VSCode.Cell language="python">
# Update step
y = np.array([[1]]) # Example measurement
z = 1
S = y @ P_pred @ y.T + np.array([[0]]) # Measurement noise covariance
K = P_pred @ y.T @ np.linalg.inv(S)
x = x_pred + K * (z - y) # Update state estimate
P = (np.eye(1) - K @ y) @ P_pred # Update error covariance
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 7. Section: Simulate System and Measurements
</VSCode.Cell>
<VSCode.Cell language="python">
# Simulate system and measurements
measurements = np.array([1, 2, 3, 4, 5])
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 8. Section: Run Kalman Filter for Multiple Steps
</VSCode.Cell>
<VSCode.Cell language="python">
# Run Kalman Filter for multiple steps
for z in measurements:
    # Prediction step
x_pred = x
P_pred = P

    # Update step
y = np.array([[z]]) # Example measurement
z = z
S = y @ P_pred @ y.T + np.array([[0]]) # Measurement noise covariance
K = P_pred @ y.T @ np.linalg.inv(S)
x = x_pred + K * (z - y) # Update state estimate
P = (np.eye(1) - K @ y) @ P_pred # Update error covariance
    print(f"Measurement: {z}, Estimated State: {x[0][0]}")
</VSCode.Cell>
<VSCode.Cell language="markdown">
## 9. Section: Visualize Results
</VSCode.Cell>
```
